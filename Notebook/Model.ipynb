# %% [markdown]
# ##Importing Dataset to colab folder

# %% [markdown]
# Upload the dataset in colab folder

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-4a8235db-6089-4fc5-a1f8-447865a2333c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a8235db-6089-4fc5-a1f8-447865a2333c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##**Reading Dataset**

# %% [markdown]
# ###Importing Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sklearn

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ###Reading data set
#
#
#
# 1.   Loading dataset using pandas
# 2.   View them

# %%
df_train = pd.read_csv('/content/drive/MyDrive/My File/modified_train.csv')

# %%
df_train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.066132
# 4           NCD19         8.93       Non-Edible         0.066132
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998       Small               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales   New_Item_Type
# 0  Supermarket Type1          3735.1380            Food
# 1  Supermarket Type2           443.4228          Drinks
# 2  Supermarket Type1          2097.2700            Food
# 3      Grocery Store           732.3800            Food
# 4  Supermarket Type1           994.7052  Non-Consumable

# %%
df_test = pd.read_csv('/content/modified_test.csv')

# %%
df_test.head()

# %% [markdown]
# ## **Model building**

# %% [markdown]
# ### Test & Train Split

# %%
from sklearn.model_selection import train_test_split

# %%
train_df, test_df = train_test_split(df_train, test_size=0.2, random_state=42)

# %%
print('train_df.shape :', train_df.shape)
print('test_df.shape :', test_df.shape)
# Out:
# train_df.shape : (6818, 13)
# test_df.shape : (1705, 13)

# %% [markdown]
# ### Finding Target and Input Columns

# %%
train_df.head(2)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 549            FDW44          9.5          Regular         0.035206
# 7757           NCF54         18.0       Non-Edible         0.047473
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 549   Fruits and Vegetables  171.3448            OUT049
# 7757              Household  170.5422            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 549                        1999      Medium               Tier 1
# 7757                       2002       Small               Tier 2
#
#             Outlet_Type  Item_Outlet_Sales   New_Item_Type
# 549   Supermarket Type1          2386.2272            Food
# 7757  Supermarket Type1          3103.9596  Non-Consumable

# %%
train_df.iloc[:,[1,2,3,5,6,7,8,9,10,12]]
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility  Item_MRP  \
# 549         9.500          Regular         0.035206  171.3448
# 7757       18.000       Non-Edible         0.047473  170.5422
# 764        17.600          Regular         0.076122  111.7202
# 6867        8.325          Low Fat         0.029845   41.6138
# 2716       12.850          Low Fat         0.137228  155.5630
# ...           ...              ...              ...       ...
# 5734        9.395          Regular         0.286345  139.1838
# 5191       15.600          Low Fat         0.117575   75.6670
# 5390       17.600       Non-Edible         0.018944  237.3590
# 860        20.350          Low Fat         0.054363  117.9466
# 7270       16.350       Non-Edible         0.016993   95.7410
#
#      Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 549             OUT049                       1999      Medium
# 7757            OUT045                       2002       Small
# 764             OUT046                       1997       Small
# 6867            OUT045                       2002       Small
# 2716            OUT046                       1997       Small
# ...                ...                        ...         ...
# 5734            OUT010                       1998       Small
# 5191            OUT017                       2007       Small
# 5390            OUT045                       2002       Small
# 860             OUT017                       2007       Small
# 7270            OUT046                       1997       Small
#
#      Outlet_Location_Type        Outlet_Type   New_Item_Type
# 549                Tier 1  Supermarket Type1            Food
# 7757               Tier 2  Supermarket Type1  Non-Consumable
# 764                Tier 1  Supermarket Type1            Food
# 6867               Tier 2  Supermarket Type1            Food
# 2716               Tier 1  Supermarket Type1            Food
# ...                   ...                ...             ...
# 5734               Tier 3      Grocery Store            Food
# 5191               Tier 2  Supermarket Type1            Food
# 5390               Tier 2  Supermarket Type1  Non-Consumable
# 860                Tier 2  Supermarket Type1            Food
# 7270               Tier 1  Supermarket Type1  Non-Consumable
#
# [6818 rows x 10 columns]

# %%
X_column=  list(train_df.iloc[:,[1,2,3,5,6,7,8,9,10,12]])
y_column = 'Item_Outlet_Sales'

# %%
X_column
# Out:
# ['Item_Weight',
#  'Item_Fat_Content',
#  'Item_Visibility',
#  'Item_MRP',
#  'Outlet_Identifier',
#  'Outlet_Establishment_Year',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type',
#  'New_Item_Type']

# %%
y_column
# Out:
# 'Item_Outlet_Sales'

# %% [markdown]
# We can now create a copy of inputs and targets for the training and test sets for further processing and model training without disturbing the original data.

# %%
X_train = train_df[X_column].copy()
y_train = train_df[y_column].copy()

# %%
X_test = test_df[X_column].copy()
y_test = test_df[y_column].copy()

# %%
X_train.head()
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility  Item_MRP  \
# 549         9.500          Regular         0.035206  171.3448
# 7757       18.000       Non-Edible         0.047473  170.5422
# 764        17.600          Regular         0.076122  111.7202
# 6867        8.325          Low Fat         0.029845   41.6138
# 2716       12.850          Low Fat         0.137228  155.5630
#
#      Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 549             OUT049                       1999      Medium
# 7757            OUT045                       2002       Small
# 764             OUT046                       1997       Small
# 6867            OUT045                       2002       Small
# 2716            OUT046                       1997       Small
#
#      Outlet_Location_Type        Outlet_Type   New_Item_Type
# 549                Tier 1  Supermarket Type1            Food
# 7757               Tier 2  Supermarket Type1  Non-Consumable
# 764                Tier 1  Supermarket Type1            Food
# 6867               Tier 2  Supermarket Type1            Food
# 2716               Tier 1  Supermarket Type1            Food

# %%
y_train.head()
# Out:
# 549     2386.2272
# 7757    3103.9596
# 764     1125.2020
# 6867     284.2966
# 2716    4224.5010
# Name: Item_Outlet_Sales, dtype: float64

# %%
X_test.head()
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility  Item_MRP  \
# 7503       14.300          Low Fat         0.026300   79.4302
# 2957        7.930       Non-Edible         0.071136   42.7086
# 7031       14.500          Regular         0.041313   42.0454
# 1084       13.000          Regular         0.044767  173.7054
# 856        10.195          Regular         0.012456  197.5110
#
#      Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 7503            OUT013                       1987        High
# 2957            OUT046                       1997       Small
# 7031            OUT049                       1999      Medium
# 1084            OUT027                       1985      Medium
# 856             OUT035                       2004       Small
#
#      Outlet_Location_Type        Outlet_Type   New_Item_Type
# 7503               Tier 3  Supermarket Type1            Food
# 2957               Tier 1  Supermarket Type1  Non-Consumable
# 7031               Tier 1  Supermarket Type1            Food
# 1084               Tier 3  Supermarket Type3          Drinks
# 856                Tier 2  Supermarket Type1            Food

# %%
y_test.head()
# Out:
# 7503    1743.0644
# 2957     356.8688
# 7031     377.5086
# 1084    5778.4782
# 856     2356.9320
# Name: Item_Outlet_Sales, dtype: float64

# %% [markdown]
# ### Numerical / Categorical data

# %%
X_train.head(2)
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility  Item_MRP  \
# 549           9.5          Regular         0.035206  171.3448
# 7757         18.0       Non-Edible         0.047473  170.5422
#
#      Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 549             OUT049                       1999      Medium
# 7757            OUT045                       2002       Small
#
#      Outlet_Location_Type        Outlet_Type   New_Item_Type
# 549                Tier 1  Supermarket Type1            Food
# 7757               Tier 2  Supermarket Type1  Non-Consumable

# %%
numeric_columns = X_train.select_dtypes(include=np.number).columns.tolist()

# %%
numeric_columns
# Out:
# ['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Outlet_Establishment_Year']

# %%
categorical_columns = X_train.select_dtypes(include='object').columns.tolist()

# %%
categorical_columns
# Out:
# ['Item_Fat_Content',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type',
#  'New_Item_Type']

# %%
X_train[numeric_columns].describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  6818.000000      6818.000000  6818.000000                6818.000000
# mean     12.907901         0.070239   141.905134                1997.856850
# std       4.644588         0.048520    62.547789                   8.395692
# min       4.555000         0.003575    31.290000                1985.000000
# 25%       8.895000         0.033084    94.175200                1987.000000
# 50%      12.650000         0.063021   144.262800                1999.000000
# 75%      17.000000         0.094791   186.855600                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000

# %% [markdown]
# #### Imputing numeric columns

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='median')

# %%
imputer.fit(df_train[numeric_columns])
# Out:
# SimpleImputer(strategy='median')

# %%
X_train[numeric_columns] = imputer.transform(X_train[numeric_columns])
X_test[numeric_columns] = imputer.transform(X_test[numeric_columns])

# %%
X_test[numeric_columns].isna().sum()
# Out:
# Item_Weight                  0
# Item_Visibility              0
# Item_MRP                     0
# Outlet_Establishment_Year    0
# dtype: int64

# %%
X_train[numeric_columns].isna().sum()
# Out:
# Item_Weight                  0
# Item_Visibility              0
# Item_MRP                     0
# Outlet_Establishment_Year    0
# dtype: int64

# %% [markdown]
# ### Scaling numeric values

# %% [markdown]
# Let's use MinMaxScaler from sklearn.preprocessing to scale values to the  (0,1)  range

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(df_train[numeric_columns])
# Out:
# MinMaxScaler()

# %%
X_train[numeric_columns] = scaler.transform(X_train[numeric_columns])
X_test[numeric_columns] = scaler.transform(X_test[numeric_columns])

# %%
X_train[numeric_columns].describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  6818.000000      6818.000000  6818.000000                6818.000000
# mean      0.497345         0.205237     0.469507                   0.535702
# std       0.276546         0.149376     0.265485                   0.349821
# min       0.000000         0.000000     0.000000                   0.000000
# 25%       0.258410         0.090849     0.266917                   0.083333
# 50%       0.481989         0.183015     0.479514                   0.583333
# 75%       0.740994         0.280823     0.660300                   0.791667
# max       1.000000         1.000000     1.000000                   1.000000

# %%
X_train.head(2)
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility  Item_MRP  \
# 549      0.294433          Regular         0.097382  0.594464
# 7757     0.800536       Non-Edible         0.135149  0.591057
#
#      Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 549             OUT049                   0.583333      Medium
# 7757            OUT045                   0.708333       Small
#
#      Outlet_Location_Type        Outlet_Type   New_Item_Type
# 549                Tier 1  Supermarket Type1            Food
# 7757               Tier 2  Supermarket Type1  Non-Consumable

# %% [markdown]
# We have scaled the values

# %% [markdown]
# ### Encoding categorical values

# %%
X_train[categorical_columns].nunique()
# Out:
# Item_Fat_Content         3
# Outlet_Identifier       10
# Outlet_Size              3
# Outlet_Location_Type     3
# Outlet_Type              4
# New_Item_Type            3
# dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder(sparse=False,handle_unknown='ignore')

# %%
df = df_train[categorical_columns]

# %%
encoder.fit(df)
# Out:
# OneHotEncoder(handle_unknown='ignore', sparse=False)

# %%
encoder.categories_
# Out:
# [array(['Low Fat', 'Non-Edible', 'Regular'], dtype=object),
#  array(['OUT010', 'OUT013', 'OUT017', 'OUT018', 'OUT019', 'OUT027',
#         'OUT035', 'OUT045', 'OUT046', 'OUT049'], dtype=object),
#  array(['High', 'Medium', 'Small'], dtype=object),
#  array(['Tier 1', 'Tier 2', 'Tier 3'], dtype=object),
#  array(['Grocery Store', 'Supermarket Type1', 'Supermarket Type2',
#         'Supermarket Type3'], dtype=object),
#  array(['Drinks', 'Food', 'Non-Consumable'], dtype=object)]

# %%
encoded_columns = list(encoder.get_feature_names(categorical_columns))
print(encoded_columns)
# Out:
# ['Item_Fat_Content_Low Fat', 'Item_Fat_Content_Non-Edible', 'Item_Fat_Content_Regular', 'Outlet_Identifier_OUT010', 'Outlet_Identifier_OUT013', 'Outlet_Identifier_OUT017', 'Outlet_Identifier_OUT018', 'Outlet_Identifier_OUT019', 'Outlet_Identifier_OUT027', 'Outlet_Identifier_OUT035', 'Outlet_Identifier_OUT045', 'Outlet_Identifier_OUT046', 'Outlet_Identifier_OUT049', 'Outlet_Size_High', 'Outlet_Size_Medium', 'Outlet_Size_Small', 'Outlet_Location_Type_Tier 1', 'Outlet_Location_Type_Tier 2', 'Outlet_Location_Type_Tier 3', 'Outlet_Type_Grocery Store', 'Outlet_Type_Supermarket Type1', 'Outlet_Type_Supermarket Type2', 'Outlet_Type_Supermarket Type3', 'New_Item_Type_Drinks', 'New_Item_Type_Food', 'New_Item_Type_Non-Consumable']

# %%
len(encoded_columns)
# Out:
# 26

# %%
X_train[encoded_columns] = encoder.transform(X_train[categorical_columns])
X_test[encoded_columns] = encoder.transform(X_test[categorical_columns])

# %%
X_train.head(2)
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility  Item_MRP  \
# 549      0.294433          Regular         0.097382  0.594464
# 7757     0.800536       Non-Edible         0.135149  0.591057
#
#      Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 549             OUT049                   0.583333      Medium
# 7757            OUT045                   0.708333       Small
#
#      Outlet_Location_Type        Outlet_Type   New_Item_Type  ...  \
# 549                Tier 1  Supermarket Type1            Food  ...
# 7757               Tier 2  Supermarket Type1  Non-Consumable  ...
#
#       Outlet_Location_Type_Tier 1  Outlet_Location_Type_Tier 2  \
# 549                           1.0                          0.0
# 7757                          0.0                          1.0
#
#       Outlet_Location_Type_Tier 3  Outlet_Type_Grocery Store  \
# 549                           0.0                        0.0
# 7757                          0.0                        0.0
#
#       Outlet_Type_Supermarket Type1  Outlet_Type_Supermarket Type2  \
# 549                             1.0                            0.0
# 7757                            1.0                            0.0
#
#       Outlet_Type_Supermarket Type3  New_Item_Type_Drinks  New_Item_Type_Food  \
# 549                             0.0                   0.0                 1.0
# 7757                            0.0                   0.0                 0.0
#
#       New_Item_Type_Non-Consumable
# 549                            0.0
# 7757                           1.0
#
# [2 rows x 36 columns]

# %%
X_train[numeric_columns + encoded_columns]
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 549      0.294433         0.097382  0.594464                   0.583333
# 7757     0.800536         0.135149  0.591057                   0.708333
# 764      0.776719         0.223348  0.341387                   0.500000
# 6867     0.224472         0.080878  0.043819                   0.708333
# 2716     0.493897         0.411473  0.527478                   0.500000
# ...           ...              ...       ...                        ...
# 5734     0.288181         0.870554  0.457956                   0.541667
# 5191     0.657636         0.350967  0.188359                   0.916667
# 5390     0.776719         0.047316  0.874662                   0.708333
# 860      0.940458         0.156359  0.367815                   0.916667
# 7270     0.702292         0.041311  0.273563                   0.500000
#
#       Item_Fat_Content_Low Fat  Item_Fat_Content_Non-Edible  \
# 549                        0.0                          0.0
# 7757                       0.0                          1.0
# 764                        0.0                          0.0
# 6867                       1.0                          0.0
# 2716                       1.0                          0.0
# ...                        ...                          ...
# 5734                       0.0                          0.0
# 5191                       1.0                          0.0
# 5390                       0.0                          1.0
# 860                        1.0                          0.0
# 7270                       0.0                          1.0
#
#       Item_Fat_Content_Regular  Outlet_Identifier_OUT010  \
# 549                        1.0                       0.0
# 7757                       0.0                       0.0
# 764                        1.0                       0.0
# 6867                       0.0                       0.0
# 2716                       0.0                       0.0
# ...                        ...                       ...
# 5734                       1.0                       1.0
# 5191                       0.0                       0.0
# 5390                       0.0                       0.0
# 860                        0.0                       0.0
# 7270                       0.0                       0.0
#
#       Outlet_Identifier_OUT013  Outlet_Identifier_OUT017  ...  \
# 549                        0.0                       0.0  ...
# 7757                       0.0                       0.0  ...
# 764                        0.0                       0.0  ...
# 6867                       0.0                       0.0  ...
# 2716                       0.0                       0.0  ...
# ...                        ...                       ...  ...
# 5734                       0.0                       0.0  ...
# 5191                       0.0                       1.0  ...
# 5390                       0.0                       0.0  ...
# 860                        0.0                       1.0  ...
# 7270                       0.0                       0.0  ...
#
#       Outlet_Location_Type_Tier 1  Outlet_Location_Type_Tier 2  \
# 549                           1.0                          0.0
# 7757                          0.0                          1.0
# 764                           1.0                          0.0
# 6867                          0.0                          1.0
# 2716                          1.0                          0.0
# ...                           ...                          ...
# 5734                          0.0                          0.0
# 5191                          0.0                          1.0
# 5390                          0.0                          1.0
# 860                           0.0                          1.0
# 7270                          1.0                          0.0
#
#       Outlet_Location_Type_Tier 3  Outlet_Type_Grocery Store  \
# 549                           0.0                        0.0
# 7757                          0.0                        0.0
# 764                           0.0                        0.0
# 6867                          0.0                        0.0
# 2716                          0.0                        0.0
# ...                           ...                        ...
# 5734                          1.0                        1.0
# 5191                          0.0                        0.0
# 5390                          0.0                        0.0
# 860                           0.0                        0.0
# 7270                          0.0                        0.0
#
#       Outlet_Type_Supermarket Type1  Outlet_Type_Supermarket Type2  \
# 549                             1.0                            0.0
# 7757                            1.0                            0.0
# 764                             1.0                            0.0
# 6867                            1.0                            0.0
# 2716                            1.0                            0.0
# ...                             ...                            ...
# 5734                            0.0                            0.0
# 5191                            1.0                            0.0
# 5390                            1.0                            0.0
# 860                             1.0                            0.0
# 7270                            1.0                            0.0
#
#       Outlet_Type_Supermarket Type3  New_Item_Type_Drinks  New_Item_Type_Food  \
# 549                             0.0                   0.0                 1.0
# 7757                            0.0                   0.0                 0.0
# 764                             0.0                   0.0                 1.0
# 6867                            0.0                   0.0                 1.0
# 2716                            0.0                   0.0                 1.0
# ...                             ...                   ...                 ...
# 5734                            0.0                   0.0                 1.0
# 5191                            0.0                   0.0                 1.0
# 5390                            0.0                   0.0                 0.0
# 860                             0.0                   0.0                 1.0
# 7270                            0.0                   0.0                 0.0
#
#       New_Item_Type_Non-Consumable
# 549                            0.0
# 7757                           1.0
# 764                            0.0
# 6867                           0.0
# 2716                           0.0
# ...                            ...
# 5734                           0.0
# 5191                           0.0
# 5390                           1.0
# 860                            0.0
# 7270                           1.0
#
# [6818 rows x 30 columns]

# %%
X_train_df = X_train[numeric_columns + encoded_columns]

# %%
X_test_df = X_test[numeric_columns + encoded_columns]

# %%
X_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6818 entries, 549 to 7270
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Item_Weight                    6818 non-null   float64
#  1   Item_Visibility                6818 non-null   float64
#  2   Item_MRP                       6818 non-null   float64
#  3   Outlet_Establishment_Year      6818 non-null   float64
#  4   Item_Fat_Content_Low Fat       6818 non-null   float64
#  5   Item_Fat_Content_Non-Edible    6818 non-null   float64
#  6   Item_Fat_Content_Regular       6818 non-null   float64
#  7   Outlet_Identifier_OUT010       6818 non-null   float64
#  8   Outlet_Identifier_OUT013       6818 non-null   float64
#  9   Outlet_Identifier_OUT017       6818 non-null   float64
#  10  Outlet_Identifier_OUT018       6818 non-null   float64
#  11  Outlet_Identifier_OUT019       6818 non-null   float64
#  12  Outlet_Identifier_OUT027       6818 non-null   float64
#  13  Outlet_Identifier_OUT035       6818 non-null   float64
#  14  Outlet_Identifier_OUT045       6818 non-null   float64
#  15  Outlet_Identifier_OUT046       6818 non-null   float64
#  16  Outlet_Identifier_OUT049       6818 non-null   float64
#  17  Outlet_Size_High               6818 non-null   float64
#  18  Outlet_Size_Medium             6818 non-null   float64
#  19  Outlet_Size_Small              6818 non-null   float64
#  20  Outlet_Location_Type_Tier 1    6818 non-null   float64
#  21  Outlet_Location_Type_Tier 2    6818 non-null   float64
#  22  Outlet_Location_Type_Tier 3    6818 non-null   float64
#  23  Outlet_Type_Grocery Store      6818 non-null   float64
#  24  Outlet_Type_Supermarket Type1  6818 non-null   float64
#  25  Outlet_Type_Supermarket Type2  6818 non-null   float64
#  26  Outlet_Type_Supermarket Type3  6818 non-null   float64
#  27  New_Item_Type_Drinks           6818 non-null   float64
#  28  New_Item_Type_Food             6818 non-null   float64
#  29  New_Item_Type_Non-Consumable   6818 non-null   float64
# dtypes: float64(30)
# memory usage: 1.6 MB

# %% [markdown]
# ## **Model Training**

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model_lin = LinearRegression()

# %%
model_lin.fit(X_train_df, y_train)
# Out:
# LinearRegression()

# %%
y_pred_lin=model_lin.predict(X_test_df)

# %%
y_pred_lin
# Out:
# array([1373.95413403,  687.12097622,  858.4071134 , ...,  828.60434808,
#         581.21503287, 1720.70502732])

# %%
y_test
# Out:
# 7503    1743.0644
# 2957     356.8688
# 7031     377.5086
# 1084    5778.4782
# 856     2356.9320
#           ...
# 7205    3004.0896
# 3257     890.8404
# 6346     629.1810
# 6318     253.0040
# 6339     976.7286
# Name: Item_Outlet_Sales, Length: 1705, dtype: float64

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred_lin)
# Out:
# 0.581089128077704

# %%
from sklearn import metrics
print('Accuracy:', round(model_lin.score(X_test_df,y_test)*100,2))
print('MAE:', metrics.mean_absolute_error(y_test, y_pred_lin))
print('MSE:', metrics.mean_squared_error(y_test, y_pred_lin))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_lin)))
# Out:
# Accuracy: 58.11
# MAE: 790.54788752432
# MSE: 1138587.2104651125
# RMSE: 1067.046020781256

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_squared_error,make_scorer

# %%
DT = DecisionTreeRegressor()

# %%
param = {
    'max_depth':[6,9,12,15],
    'min_samples_leaf':[10,50,100,150]
}

# %%
random_search = RandomizedSearchCV(DT,param_distributions=param,n_iter=5,scoring=make_scorer(mean_squared_error),n_jobs=-1,cv=5,verbose=3)

# %%
random_search.fit(X_train_df, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_iter=5, n_jobs=-1,
#                    param_distributions={'max_depth': [6, 9, 12, 15],
#                                         'min_samples_leaf': [10, 50, 100, 150]},
#                    scoring=make_scorer(mean_squared_error), verbose=3)

# %%
means = random_search.cv_results_['mean_test_score']
params = random_search.cv_results_['params']
for mean, param in zip(means, params):
    print("%f with: %r" % (mean, param))
    if mean == min(means):
        print('Best parameters with the minimum Mean Square Error are:',param)
# Out:
# 1249481.786662 with: {'min_samples_leaf': 150, 'max_depth': 12}
# 1253587.240535 with: {'min_samples_leaf': 50, 'max_depth': 12}
# 1449404.382734 with: {'min_samples_leaf': 10, 'max_depth': 12}
# 1233478.928570 with: {'min_samples_leaf': 10, 'max_depth': 6}
# 1216915.170973 with: {'min_samples_leaf': 50, 'max_depth': 6}
# Best parameters with the minimum Mean Square Error are: {'min_samples_leaf': 50, 'max_depth': 6}

# %%
DT = DecisionTreeRegressor(min_samples_leaf=50, max_depth=6)
DT.fit(X_train_df,y_train)
# Out:
# DecisionTreeRegressor(max_depth=6, min_samples_leaf=50)

# %%
DT_predict = DT.predict(X_test_df)

# %%
DT_predict
# Out:
# array([1366.53523034,  704.13315912,  704.13315912, ...,  704.13315912,
#         704.13315912, 1642.74411908])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,DT_predict)
# Out:
# 0.6128345399904291

# %%
from sklearn import metrics
print('Accuracy:', round(DT.score(X_test_df,y_test)*100,2))
print('MAE:', metrics.mean_absolute_error(y_test, DT_predict))
print('MSE:', metrics.mean_squared_error(y_test, DT_predict))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, DT_predict)))
# Out:
# Accuracy: 61.28
# MAE: 719.3955276618045
# MSE: 1052304.1311339072
# RMSE: 1025.8187613481766

# %% [markdown]
# ### Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,make_scorer
from sklearn.model_selection import RandomizedSearchCV

# %%
rf = RandomForestRegressor()

# %%
param = {
    'max_depth':[3,6,9,12,15],
    'n_estimators' : [10,50,100,150,200] 
}

# %%
rf_search = RandomizedSearchCV(rf,param_distributions=param,n_iter=5,scoring=make_scorer(mean_squared_error),n_jobs=-1,cv=5,verbose=3)

# %%
rf_search.fit(X_train_df, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_iter=5, n_jobs=-1,
#                    param_distributions={'max_depth': [3, 6, 9, 12, 15],
#                                         'n_estimators': [10, 50, 100, 150,
#                                                          200]},
#                    scoring=make_scorer(mean_squared_error), verbose=3)

# %%
means = rf_search.cv_results_['mean_test_score']
params = rf_search.cv_results_['params']
for mean, param in zip(means, params):
    print("%f with: %r" % (mean, param))
    if mean == min(means):
        print('Best parameters with the minimum Mean Square Error are:',param)
# Out:
# 1226758.517140 with: {'n_estimators': 150, 'max_depth': 9}
# 1262612.383547 with: {'n_estimators': 150, 'max_depth': 12}
# 1211025.044481 with: {'n_estimators': 150, 'max_depth': 6}
# Best parameters with the minimum Mean Square Error are: {'n_estimators': 150, 'max_depth': 6}
# 1375029.322269 with: {'n_estimators': 10, 'max_depth': 15}
# 1240052.083380 with: {'n_estimators': 50, 'max_depth': 9}

# %%
rf = RandomForestRegressor(n_estimators=150, max_depth=6)
rf.fit(X_train_df,y_train)
# Out:
# RandomForestRegressor(max_depth=6, n_estimators=150)

# %%
rf_pred =  rf.predict(X_test_df)

# %%
rf_pred
# Out:
# array([1258.71964532,  670.14813123,  662.63342904, ...,  662.63342904,
#         734.71366926, 1670.8810444 ])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,rf_pred)
# Out:
# 0.6170610098589755

# %%
from sklearn import metrics
print('Accuracy:', round(rf.score(X_test_df,y_test)*100,2))
print('MAE:', metrics.mean_absolute_error(y_test, rf_pred))
print('MSE:', metrics.mean_squared_error(y_test, rf_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, rf_pred)))
# Out:
# Accuracy: 61.71
# MAE: 713.2252021129052
# MSE: 1040816.7125437406
# RMSE: 1020.2042504046632

# %% [markdown]
# ### Save the model

# %%
import joblib

# %%
joblib.dump(DT, "Decision_tree_model.pkl",compress=2)
# Out:
# ['Decision_tree_model.pkl']

# %%
joblib.dump(rf, "RForest_fitted_model.pkl",compress=2)
# Out:
# ['RForest_fitted_model.pkl']

# %%
joblib.dump(imputer, "imputer.pkl")
joblib.dump(scaler, "scaler.pkl")
joblib.dump(encoder, "encoder.pkl")
joblib.dump(X_column, "input_columns.pkl")
joblib.dump(y_column, "target_column.pkl")
joblib.dump(numeric_columns, "numeric_columns.pkl")
joblib.dump(categorical_columns, "categorical_columns.pkl")
joblib.dump(encoded_columns, "encoded_columns.pkl")
# Out:
# ['encoded_columns.pkl']

# %%
import pandas as pd
pd. __version__
# Out:
# '1.3.5'

# %%
import numpy as np
np.__version__
# Out:
# '1.21.6'

# %%
import joblib as jb
jb.__version__
# Out:
# '1.1.0'

# %%
import sklearn
sklearn.__version__
# Out:
# '1.0.2'

# %%
import pickle 
print(pickle.format_version)
# Out:
# 4.0
